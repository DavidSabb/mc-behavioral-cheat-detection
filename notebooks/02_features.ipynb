# %%
import sys
sys.path.append("../src")

from load import load_sessions, load_movement, load_combat, load_clicks, clean_movement, trim_edges
from features import build_feature_table

sessions = load_sessions()
movement = load_movement(sessions)
movement = trim_edges(movement, sessions)
movement, report = clean_movement(movement)
print(report)

combat = load_combat(sessions)
clicks = load_clicks(sessions)

X = build_feature_table(movement, combat, clicks, sessions)
print(X.shape)
X.head()
# Out:
# {'teleports': np.int64(4), 'time_gaps': np.int64(3432), 'kept': 100805, 'removed_pct': 3.2962078260952983}
# Total sessions to process: 20
#   session 00ced661: 3159 rows, 10 windows
#   session 0376956a: 4444 rows, 18 windows
#   session 0a3f23fe: 3085 rows, 11 windows
#   session 0afcc142: 2452 rows, 8 windows
#   session 0f7a4633: 2969 rows, 10 windows
#   session 144e25a6: 7382 rows, 27 windows
#   session 2f2ee5d1: 980 rows, 4 windows
#   session 3fcaedd0: 429 rows, 3 windows
#   session 4f4e5f20: 4418 rows, 15 windows
#   session 78881ac8: 3216 rows, 11 windows
#   session 9218cb49: 6396 rows, 22 windows
#   session 9c37db4d: 11976 rows, 74 windows
#   session a40b7208: 7089 rows, 26 windows
#   session bfcc6a83: 2577 rows, 12 windows
#   session c3f14171: 10592 rows, 36 windows
#   session ce7622db: 9957 rows, 37 windows
#   session d044d722: 2250 rows, 8 windows
#   session d68727e5: 2500 rows, 9 windows
#   session eae9200c: 205 rows, 1 windows
#   session ef70dd7f: 14729 rows, 51 windows
# (369, 40)
#      window_id session_id  yaw_gcd   yaw_std  yaw_kurtosis  yaw_skew  yaw_max  \
# 0  00ced661_w0   00ced661  0.04025  2.890377      3.786799  0.634935  13.5424
# 1  00ced661_w1   00ced661  0.04010  3.216991      4.987852  1.494007  20.4752
# 2  00ced661_w2   00ced661  0.03960  3.645080      3.239243  0.519019  20.4752
# 3  00ced661_w3   00ced661  0.03980  3.077339      2.151547 -0.057175  12.1477
# 4  00ced661_w4   00ced661  0.03995  2.074765      5.678029 -1.349171  13.6030
#
#      yaw_p99  yaw_pitch_ratio  pitch_zero_frac  ...     iv_cv  iv_kurtosis  \
# 0   9.455188        14.050654         0.363322  ...  0.321201    -1.417935
# 1  12.025616        19.225374         0.377816  ...  0.328744    -1.258989
# 2  11.780610        15.560564         0.331034  ...  0.329069    -1.183940
# 3  10.251750        12.787733         0.306261  ...  0.322080    -1.537180
# 4   7.532344        10.449971         0.305882  ...  0.316537    -1.763954
#
#     iv_skew  iv_min  iv_unique_frac  iv_p95_p50  iv_mean_median        label  \
# 0 -0.147286    49.0        0.026667        1.01        0.800000  AUTOCLICKER
# 1 -0.037574    49.0        0.029333        1.01        0.798640  AUTOCLICKER
# 2 -0.030953    49.0        0.026738        1.02        0.803289  AUTOCLICKER
# 3 -0.158090    49.0        0.023873        1.01        0.794271  AUTOCLICKER
# 4 -0.249376    49.0        0.023747        1.01        0.791108  AUTOCLICKER
#
#    player  is_cheat
# 0  tavitt         1
# 1  tavitt         1
# 2  tavitt         1
# 3  tavitt         1
# 4  tavitt         1
#
# [5 rows x 40 columns]

# %%
X.to_parquet("../data/processed/features.parquet")
print("Saved:", X.shape)
# Out:
# Saved: (369, 40)
